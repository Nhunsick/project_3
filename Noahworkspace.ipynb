# %%
# %run EDA.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3114 entries, 0 to 3113
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3114 non-null   object
#  1   county                  3114 non-null   object
#  2   fips                    3114 non-null   int64
#  3   trump16                 3114 non-null   int64
#  4   clinton16               3114 non-null   int64
#  5   otherpres16             3114 non-null   int64
#  6   romney12                3114 non-null   int64
#  7   obama12                 3114 non-null   int64
#  8   otherpres12             3114 non-null   int64
#  9   demsen16                1942 non-null   float64
#  10  repsen16                1942 non-null   float64
#  11  othersen16              1942 non-null   float64
#  12  demhouse16              2862 non-null   float64
#  13  rephouse16              2862 non-null   float64
#  14  otherhouse16            2862 non-null   float64
#  15  demgov16                601 non-null    float64
#  16  repgov16                601 non-null    float64
#  17  othergov16              601 non-null    float64
#  18  repgov14                2148 non-null   float64
#  19  demgov14                2148 non-null   float64
#  20  othergov14              2148 non-null   float64
#  21  total_population        3111 non-null   float64
#  22  cvap                    3111 non-null   float64
#  23  white_pct               3111 non-null   float64
#  24  black_pct               3111 non-null   float64
#  25  hispanic_pct            3111 non-null   float64
#  26  nonwhite_pct            3111 non-null   float64
#  27  foreignborn_pct         3111 non-null   float64
#  28  female_pct              3111 non-null   float64
#  29  age29andunder_pct       3111 non-null   float64
#  30  age65andolder_pct       3111 non-null   float64
#  31  median_hh_inc           3111 non-null   float64
#  32  clf_unemploy_pct        3111 non-null   float64
#  33  lesshs_pct              3111 non-null   float64
#  34  lesscollege_pct         3111 non-null   float64
#  35  lesshs_whites_pct       3111 non-null   float64
#  36  lesscollege_whites_pct  3111 non-null   float64
#  37  rural_pct               3113 non-null   float64
#  38  ruralurban_cc           3113 non-null   float64
# dtypes: float64(30), int64(7), object(2)
# memory usage: 948.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3151 entries, 0 to 3150
# Data columns (total 26 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   fips       3151 non-null   int64
#  1   name       3151 non-null   object
#  2   type       3151 non-null   object
#  3   totalvote  3151 non-null   int64
#  4   vote1      3151 non-null   int64
#  5   vote2      3151 non-null   int64
#  6   vote3      3151 non-null   int64
#  7   vote4      3151 non-null   int64
#  8   vote5      3151 non-null   int64
#  9   vote6      3151 non-null   int64
#  10  vote7      3151 non-null   int64
#  11  vote8      3151 non-null   int64
#  12  vote9      3151 non-null   int64
#  13  vote10     3151 non-null   int64
#  14  vote11     3151 non-null   int64
#  15  vote12     3151 non-null   int64
#  16  vote13     3151 non-null   int64
#  17  vote14     3151 non-null   int64
#  18  vote15     3151 non-null   int64
#  19  vote16     3151 non-null   int64
#  20  vote17     3151 non-null   int64
#  21  vote18     3151 non-null   int64
#  22  vote19     3151 non-null   int64
#  23  vote20     3151 non-null   int64
#  24  vote21     3151 non-null   int64
#  25  vote22     3151 non-null   int64
# dtypes: int64(24), object(2)
# memory usage: 640.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3111 entries, 0 to 3110
# Data columns (total 64 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3111 non-null   object
#  1   county                  3111 non-null   object
#  2   fips                    3111 non-null   int64
#  3   trump16                 3111 non-null   int64
#  4   clinton16               3111 non-null   int64
#  5   otherpres16             3111 non-null   int64
#  6   romney12                3111 non-null   int64
#  7   obama12                 3111 non-null   int64
#  8   otherpres12             3111 non-null   int64
#  9   demsen16                1942 non-null   float64
#  10  repsen16                1942 non-null   float64
#  11  othersen16              1942 non-null   float64
#  12  demhouse16              2862 non-null   float64
#  13  rephouse16              2862 non-null   float64
#  14  otherhouse16            2862 non-null   float64
#  15  demgov16                601 non-null    float64
#  16  repgov16                601 non-null    float64
#  17  othergov16              601 non-null    float64
#  18  repgov14                2148 non-null   float64
#  19  demgov14                2148 non-null   float64
#  20  othergov14              2148 non-null   float64
#  21  total_population        3110 non-null   float64
#  22  cvap                    3110 non-null   float64
#  23  white_pct               3110 non-null   float64
#  24  black_pct               3110 non-null   float64
#  25  hispanic_pct            3110 non-null   float64
#  26  nonwhite_pct            3110 non-null   float64
#  27  foreignborn_pct         3110 non-null   float64
#  28  female_pct              3110 non-null   float64
#  29  age29andunder_pct       3110 non-null   float64
#  30  age65andolder_pct       3110 non-null   float64
#  31  median_hh_inc           3110 non-null   float64
#  32  clf_unemploy_pct        3110 non-null   float64
#  33  lesshs_pct              3110 non-null   float64
#  34  lesscollege_pct         3110 non-null   float64
#  35  lesshs_whites_pct       3110 non-null   float64
#  36  lesscollege_whites_pct  3110 non-null   float64
#  37  rural_pct               3111 non-null   float64
#  38  ruralurban_cc           3111 non-null   float64
#  39  name                    3111 non-null   object
#  40  type                    3111 non-null   object
#  41  totalvote               3111 non-null   int64
#  42  vote1                   3111 non-null   int64
#  43  vote2                   3111 non-null   int64
#  44  vote3                   3111 non-null   int64
#  45  vote4                   3111 non-null   int64
#  46  vote5                   3111 non-null   int64
#  47  vote6                   3111 non-null   int64
#  48  vote7                   3111 non-null   int64
#  49  vote8                   3111 non-null   int64
#  50  vote9                   3111 non-null   int64
#  51  vote10                  3111 non-null   int64
#  52  vote11                  3111 non-null   int64
#  53  vote12                  3111 non-null   int64
#  54  vote13                  3111 non-null   int64
#  55  vote14                  3111 non-null   int64
#  56  vote15                  3111 non-null   int64
#  57  vote16                  3111 non-null   int64
#  58  vote17                  3111 non-null   int64
#  59  vote18                  3111 non-null   int64
#  60  vote19                  3111 non-null   int64
#  61  vote20                  3111 non-null   int64
#  62  vote21                  3111 non-null   int64
#  63  vote22                  3111 non-null   int64
# dtypes: float64(30), int64(30), object(4)
# memory usage: 1.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3111 entries, 0 to 3110
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3111 non-null   object
#  1   county                  3111 non-null   object
#  2   fips                    3111 non-null   int64
#  3   trump16                 3111 non-null   int64
#  4   clinton16               3111 non-null   int64
#  5   otherpres16             3111 non-null   int64
#  6   romney12                3111 non-null   int64
#  7   obama12                 3111 non-null   int64
#  8   otherpres12             3111 non-null   int64
#  9   demsen16                1942 non-null   float64
#  10  repsen16                1942 non-null   float64
#  11  othersen16              1942 non-null   float64
#  12  demhouse16              2862 non-null   float64
#  13  rephouse16              2862 non-null   float64
#  14  otherhouse16            2862 non-null   float64
#  15  demgov16                601 non-null    float64
#  16  repgov16                601 non-null    float64
#  17  othergov16              601 non-null    float64
#  18  repgov14                2148 non-null   float64
#  19  demgov14                2148 non-null   float64
#  20  othergov14              2148 non-null   float64
#  21  total_population        3110 non-null   float64
#  22  cvap                    3110 non-null   float64
#  23  white_pct               3110 non-null   float64
#  24  black_pct               3110 non-null   float64
#  25  hispanic_pct            3110 non-null   float64
#  26  nonwhite_pct            3110 non-null   float64
#  27  foreignborn_pct         3110 non-null   float64
#  28  female_pct              3110 non-null   float64
#  29  age29andunder_pct       3110 non-null   float64
#  30  age65andolder_pct       3110 non-null   float64
#  31  median_hh_inc           3110 non-null   float64
#  32  clf_unemploy_pct        3110 non-null   float64
#  33  lesshs_pct              3110 non-null   float64
#  34  lesscollege_pct         3110 non-null   float64
#  35  lesshs_whites_pct       3110 non-null   float64
#  36  lesscollege_whites_pct  3110 non-null   float64
#  37  rural_pct               3111 non-null   float64
#  38  ruralurban_cc           3111 non-null   float64
#  39  name                    3111 non-null   object
#  40  type                    3111 non-null   object
#  41  totalvote               3111 non-null   int64
#  42  vote1                   3111 non-null   int64
#  43  vote2                   3111 non-null   int64
# dtypes: float64(30), int64(10), object(4)
# memory usage: 1.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3111 entries, 0 to 3110
# Data columns (total 42 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3111 non-null   object
#  1   county                  3111 non-null   object
#  2   fips                    3111 non-null   int64
#  3   trump16                 3111 non-null   int64
#  4   clinton16               3111 non-null   int64
#  5   otherpres16             3111 non-null   int64
#  6   romney12                3111 non-null   int64
#  7   obama12                 3111 non-null   int64
#  8   otherpres12             3111 non-null   int64
#  9   demsen16                1942 non-null   float64
#  10  repsen16                1942 non-null   float64
#  11  othersen16              1942 non-null   float64
#  12  demhouse16              2862 non-null   float64
#  13  rephouse16              2862 non-null   float64
#  14  otherhouse16            2862 non-null   float64
#  15  total_population        3110 non-null   float64
#  16  cvap                    3110 non-null   float64
#  17  white_pct               3110 non-null   float64
#  18  black_pct               3110 non-null   float64
#  19  hispanic_pct            3110 non-null   float64
#  20  nonwhite_pct            3110 non-null   float64
#  21  foreignborn_pct         3110 non-null   float64
#  22  female_pct              3110 non-null   float64
#  23  age29andunder_pct       3110 non-null   float64
#  24  age65andolder_pct       3110 non-null   float64
#  25  median_hh_inc           3110 non-null   float64
#  26  clf_unemploy_pct        3110 non-null   float64
#  27  lesshs_pct              3110 non-null   float64
#  28  lesscollege_pct         3110 non-null   float64
#  29  lesshs_whites_pct       3110 non-null   float64
#  30  lesscollege_whites_pct  3110 non-null   float64
#  31  rural_pct               3111 non-null   float64
#  32  ruralurban_cc           3111 non-null   float64
#  33  name                    3111 non-null   object
#  34  type                    3111 non-null   object
#  35  totalvote               3111 non-null   int64
#  36  vote1                   3111 non-null   int64
#  37  vote2                   3111 non-null   int64
#  38  pres_16_total_votes     3111 non-null   int64
#  39  pres_12_total_votes     3111 non-null   int64
#  40  sen_16_total_votes      1942 non-null   float64
#  41  house_16_total_votes    2862 non-null   float64
# dtypes: float64(26), int64(12), object(4)
# memory usage: 1020.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3111 entries, 0 to 3110
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3111 non-null   object
#  1   fips                    3111 non-null   int64
#  2   trump16                 3111 non-null   int64
#  3   clinton16               3111 non-null   int64
#  4   otherpres16             3111 non-null   int64
#  5   romney12                3111 non-null   int64
#  6   obama12                 3111 non-null   int64
#  7   otherpres12             3111 non-null   int64
#  8   demsen16                1942 non-null   float64
#  9   repsen16                1942 non-null   float64
#  10  othersen16              1942 non-null   float64
#  11  demhouse16              2862 non-null   float64
#  12  rephouse16              2862 non-null   float64
#  13  otherhouse16            2862 non-null   float64
#  14  total_population        3110 non-null   float64
#  15  cvap                    3110 non-null   float64
#  16  white_pct               3110 non-null   float64
#  17  black_pct               3110 non-null   float64
#  18  hispanic_pct            3110 non-null   float64
#  19  nonwhite_pct            3110 non-null   float64
#  20  foreignborn_pct         3110 non-null   float64
#  21  female_pct              3110 non-null   float64
#  22  age29andunder_pct       3110 non-null   float64
#  23  age65andolder_pct       3110 non-null   float64
#  24  median_hh_inc           3110 non-null   float64
#  25  clf_unemploy_pct        3110 non-null   float64
#  26  lesshs_pct              3110 non-null   float64
#  27  lesscollege_pct         3110 non-null   float64
#  28  lesshs_whites_pct       3110 non-null   float64
#  29  lesscollege_whites_pct  3110 non-null   float64
#  30  rural_pct               3111 non-null   float64
#  31  ruralurban_cc           3111 non-null   float64
#  32  totalvote               3111 non-null   int64
#  33  vote1                   3111 non-null   int64
#  34  vote2                   3111 non-null   int64
#  35  pres_16_total_votes     3111 non-null   int64
#  36  pres_12_total_votes     3111 non-null   int64
#  37  sen_16_total_votes      1942 non-null   float64
#  38  house_16_total_votes    2862 non-null   float64
# dtypes: float64(26), int64(12), object(1)
# memory usage: 948.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 3098 entries, 0 to 3110
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3098 non-null   object
#  1   fips                    3098 non-null   int64
#  2   total_population        3097 non-null   float64
#  3   cvap                    3097 non-null   float64
#  4   white_pct               3097 non-null   float64
#  5   black_pct               3097 non-null   float64
#  6   hispanic_pct            3097 non-null   float64
#  7   nonwhite_pct            3097 non-null   float64
#  8   foreignborn_pct         3097 non-null   float64
#  9   female_pct              3097 non-null   float64
#  10  age29andunder_pct       3097 non-null   float64
#  11  age65andolder_pct       3097 non-null   float64
#  12  median_hh_inc           3097 non-null   float64
#  13  clf_unemploy_pct        3097 non-null   float64
#  14  lesshs_pct              3097 non-null   float64
#  15  lesscollege_pct         3097 non-null   float64
#  16  lesshs_whites_pct       3097 non-null   float64
#  17  lesscollege_whites_pct  3097 non-null   float64
#  18  rural_pct               3098 non-null   float64
#  19  ruralurban_cc           3098 non-null   float64
#  20  totalvote               3098 non-null   int64
#  21  vote1                   3098 non-null   int64
#  22  vote2                   3098 non-null   int64
#  23  pres_16_mov             3098 non-null   float64
#  24  pres_12_mov             3098 non-null   float64
#  25  sen_16_mov              1929 non-null   float64
#  26  house_16_mov            3098 non-null   float64
# dtypes: float64(22), int64(4), object(1)
# memory usage: 742.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 3097 entries, 0 to 3110
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3097 non-null   object
#  1   fips                    3097 non-null   int64
#  2   total_population        3097 non-null   float64
#  3   black_pct               3097 non-null   float64
#  4   hispanic_pct            3097 non-null   float64
#  5   nonwhite_pct            3097 non-null   float64
#  6   foreignborn_pct         3097 non-null   float64
#  7   female_pct              3097 non-null   float64
#  8   age29andunder_pct       3097 non-null   float64
#  9   age65andolder_pct       3097 non-null   float64
#  10  median_hh_inc           3097 non-null   float64
#  11  clf_unemploy_pct        3097 non-null   float64
#  12  lesshs_pct              3097 non-null   float64
#  13  lesscollege_pct         3097 non-null   float64
#  14  lesshs_whites_pct       3097 non-null   float64
#  15  lesscollege_whites_pct  3097 non-null   float64
#  16  rural_pct               3097 non-null   float64
#  17  pres_16_mov             3097 non-null   float64
#  18  pres_12_mov             3097 non-null   float64
#  19  house_16_mov            3097 non-null   float64
#  20  dem_win                 3097 non-null   int64
#  21  cvap_pct                3097 non-null   float64
# dtypes: float64(19), int64(2), object(1)
# memory usage: 556.5+ KB

# %%
merged_df.head()
# Out:
#      state  fips  total_population      cvap  black_pct  hispanic_pct  \
# 0  Alabama  1001           55049.0   40690.0  18.370906      2.572254
# 1  Alabama  1003          199510.0  151770.0   9.225603      4.366698
# 2  Alabama  1005           26614.0   20375.0  47.888329      4.309762
# 3  Alabama  1007           22572.0   17590.0  21.212121      2.223994
# 4  Alabama  1009           57704.0   42430.0   1.557951      8.727298
#
#    nonwhite_pct  foreignborn_pct  female_pct  age29andunder_pct  ...  \
# 0     24.316518         1.838362   51.176225          40.037058  ...
# 1     16.821212         3.269510   51.194928          35.474412  ...
# 2     54.114376         2.859397   46.498084          37.664387  ...
# 3     25.234804         1.351232   46.464646          37.329435  ...
# 4     12.342299         4.271801   50.485235          37.240053  ...
#
#    lesshs_pct  lesscollege_pct  lesshs_whites_pct  lesscollege_whites_pct  \
# 0   12.417046        75.407229          10.002112               74.065601
# 1    9.972418        70.452889           7.842227               68.405607
# 2   26.235928        87.132213          19.579752               81.364746
# 3   19.301587        88.000000          15.020490               87.471774
# 4   19.968585        86.950243          16.643368               86.163610
#
#    rural_pct  pres_16_mov  pres_12_mov  sen_16_mov  house_16_mov  dem_win
# 0  42.002162    -0.489969    -0.460304   -0.483037     -0.280756        0
# 1  42.279099    -0.571601    -0.557688   -0.587449     -0.571601        0
# 2  67.789635    -0.055688     0.031454   -0.064425      0.100637        0
# 3  68.352607    -0.551536    -0.466746   -0.520032     -0.542860        0
# 4  89.951502    -0.809090    -0.740940   -0.761559     -0.805394        0
#
# [5 rows x 23 columns]

# %%
merged_df_no_sen.head()
# Out:
#      state  fips  total_population  black_pct  hispanic_pct  nonwhite_pct  \
# 0  Alabama  1001           55049.0  18.370906      2.572254     24.316518
# 1  Alabama  1003          199510.0   9.225603      4.366698     16.821212
# 2  Alabama  1005           26614.0  47.888329      4.309762     54.114376
# 3  Alabama  1007           22572.0  21.212121      2.223994     25.234804
# 4  Alabama  1009           57704.0   1.557951      8.727298     12.342299
#
#    foreignborn_pct  female_pct  age29andunder_pct  age65andolder_pct  ...  \
# 0         1.838362   51.176225          40.037058          13.978456  ...
# 1         3.269510   51.194928          35.474412          18.714851  ...
# 2         2.859397   46.498084          37.664387          16.528895  ...
# 3         1.351232   46.464646          37.329435          14.885699  ...
# 4         4.271801   50.485235          37.240053          17.192916  ...
#
#    lesshs_pct  lesscollege_pct  lesshs_whites_pct  lesscollege_whites_pct  \
# 0   12.417046        75.407229          10.002112               74.065601
# 1    9.972418        70.452889           7.842227               68.405607
# 2   26.235928        87.132213          19.579752               81.364746
# 3   19.301587        88.000000          15.020490               87.471774
# 4   19.968585        86.950243          16.643368               86.163610
#
#    rural_pct  pres_16_mov  pres_12_mov  house_16_mov  dem_win  cvap_pct
# 0  42.002162    -0.489969    -0.460304     -0.280756        0  0.739160
# 1  42.279099    -0.571601    -0.557688     -0.571601        0  0.760714
# 2  67.789635    -0.055688     0.031454      0.100637        0  0.765575
# 3  68.352607    -0.551536    -0.466746     -0.542860        0  0.779284
# 4  89.951502    -0.809090    -0.740940     -0.805394        0  0.735304
#
# [5 rows x 22 columns]

# %%
drop_for_model = ['state', 'fips']
merged_df = merged_df.drop(columns = drop_for_model)
merged_df_no_sen = merged_df_no_sen.drop(columns = drop_for_model)
merged_df
# Out:
#       total_population      cvap  black_pct  hispanic_pct  nonwhite_pct  \
# 0              55049.0   40690.0  18.370906      2.572254     24.316518
# 1             199510.0  151770.0   9.225603      4.366698     16.821212
# 2              26614.0   20375.0  47.888329      4.309762     54.114376
# 3              22572.0   17590.0  21.212121      2.223994     25.234804
# 4              57704.0   42430.0   1.557951      8.727298     12.342299
# ...                ...       ...        ...           ...           ...
# 3106           44812.0   30565.0   0.865840     15.859591     20.184326
# 3107           22623.0   16335.0   0.614419     15.174822     18.799452
# 3108           20893.0   14355.0   0.186665      8.959939     12.281625
# 3109            8351.0    6135.0   0.790325     13.962400     17.602682
# 3110            7175.0    5565.0   0.250871      1.003484      7.777003
#
#       foreignborn_pct  female_pct  age29andunder_pct  age65andolder_pct  \
# 0            1.838362   51.176225          40.037058          13.978456
# 1            3.269510   51.194928          35.474412          18.714851
# 2            2.859397   46.498084          37.664387          16.528895
# 3            1.351232   46.464646          37.329435          14.885699
# 4            4.271801   50.485235          37.240053          17.192916
# ...               ...         ...                ...                ...
# 3106         5.509685   47.824244          44.153352           9.417120
# 3107        11.475048   48.097069          35.569995          11.837510
# 3108         3.986981   49.327526          43.205858          10.678218
# 3109         3.783978   51.359119          34.774279          19.650341
# 3110         4.083624   47.958188          33.282230          18.355401
#
#       median_hh_inc  ...  lesshs_pct  lesscollege_pct  lesshs_whites_pct  \
# 0           53099.0  ...   12.417046        75.407229          10.002112
# 1           51365.0  ...    9.972418        70.452889           7.842227
# 2           33956.0  ...   26.235928        87.132213          19.579752
# 3           39776.0  ...   19.301587        88.000000          15.020490
# 4           46212.0  ...   19.968585        86.950243          16.643368
# ...             ...  ...         ...              ...                ...
# 3106        68233.0  ...    9.314606        78.628507           6.238463
# 3107        75594.0  ...    4.633570        46.211584           1.526877
# 3108        53323.0  ...   10.361224        81.793082           8.806312
# 3109        46212.0  ...   12.577108        78.923920          10.299738
# 3110        55640.0  ...    8.592392        81.193281           7.342144
#
#       lesscollege_whites_pct  rural_pct  pres_16_mov  pres_12_mov  sen_16_mov  \
# 0                  74.065601  42.002162    -0.489969    -0.460304   -0.483037
# 1                  68.405607  42.279099    -0.571601    -0.557688   -0.587449
# 2                  81.364746  67.789635    -0.055688     0.031454   -0.064425
# 3                  87.471774  68.352607    -0.551536    -0.466746   -0.520032
# 4                  86.163610  89.951502    -0.809090    -0.740940   -0.761559
# ...                      ...        ...          ...          ...         ...
# 3106               76.606813  10.916313    -0.520899    -0.393844         NaN
# 3107               41.769504  46.430920     0.268710     0.118196         NaN
# 3108               81.080852  43.095937    -0.584652    -0.584026         NaN
# 3109               75.980688  35.954529    -0.623755    -0.562880         NaN
# 3110               81.141179  54.536626    -0.775383    -0.714201         NaN
#
#       house_16_mov  dem_win
# 0        -0.280756        0
# 1        -0.571601        0
# 2         0.100637        0
# 3        -0.542860        0
# 4        -0.805394        0
# ...            ...      ...
# 3106     -0.155873        0
# 3107      0.236655        1
# 3108     -0.450408        0
# 3109     -0.500388        0
# 3110     -0.514838        0
#
# [3097 rows x 21 columns]

# %%
from sklearn.model_selection import train_test_split
X = merged_df_no_sen.drop(columns = 'dem_win')
y = merged_df_no_sen['dem_win']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 21)

# %%
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression

def cross_validation(X_train, y_train, c, num_split = 10):
    
    X_train = X_train.values
    y_train = y_train.values
    
    score_train_list = []
    score_val_list = []
    
    for train_index, valid_index in KFold(n_splits = num_split).split(X_train):
        X_train_fold, X_val_fold = X_train[train_index], X_train[valid_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[valid_index]
        scaler = MinMaxScaler()
        X_tf_sc = scaler.fit_transform(X_train_fold)
        X_vld_sc = scaler.transform(X_val_fold)

        logreg = LogisticRegression(fit_intercept=False, solver='liblinear', C = c)
        logreg.fit(X_tf_sc, y_train_fold)

        accuracy_train = logreg.score(X_tf_sc, y_train_fold)
        accuracy_val = logreg.score(X_vld_sc, y_val_fold)
        score_val_list.append(accuracy_val)
        score_train_list.append(accuracy_train)
    return {'c': c, 'train': np.mean(score_train_list), 'validation': np.mean(score_val_list)}

# %%
C_list = [1e-4,1e-3, 1e-2, 1e-1, 1, 10, 100, 1e3, 1e4]
crossval_df = pd.DataFrame(columns = ['c', 'train', 'validation'])
for c in C_list:
    crossval_df = crossval_df._append(cross_validation(X_train, y_train, c, 10), ignore_index = True)

# %%
crossval_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   c           9 non-null      float64
#  1   train       9 non-null      float64
#  2   validation  9 non-null      float64
# dtypes: float64(3)
# memory usage: 344.0 bytes

# %%
crossval_df.iloc[crossval_df['validation'].idxmax()]
# Out:
# c             100.000000
# train           0.962293
# validation      0.962524
# Name: 6, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots()
sns.lineplot(x = np.log10(C_list), y = crossval_df['validation'], marker = 's', ax = ax)
ax.set_xlabel('Log(C)')
ax.set_ylabel('Mean Accuracy')
ax.set_title('Accuracy averaged on validation folds')
plt.show()

# %%
fulltrain_scaler = MinMaxScaler()
X_train_scaled = fulltrain_scaler.fit_transform(X_train)
X_test_scaled = fulltrain_scaler.transform(X_test)
logreg_final = LogisticRegression(fit_intercept = False, solver = 'liblinear', C = 10)
logreg_final.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(C=10, fit_intercept=False, solver='liblinear')

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score
y_hat_test = logreg_final.predict(X_test_scaled)
y_hat_train = logreg_final.predict(X_train_scaled)
print('Training Precision: ', precision_score(y_train, y_hat_train))
print('Testing Precision: ', precision_score(y_test, y_hat_test))
print('\n\n')
print('Training Recall: ', recall_score(y_train, y_hat_train))
print('Testing Recall: ', recall_score(y_test, y_hat_test))
print('\n\n')
print('Training Accuracy: ', accuracy_score(y_train, y_hat_train))
print('Testing Accuracy: ', accuracy_score(y_test, y_hat_test))
print('\n\n')
print('Training F1-Score: ', f1_score(y_train, y_hat_train))
print('Testing F1-Score: ', f1_score(y_test, y_hat_test))
# Out:
# Training Precision:  0.9232365145228216
# Testing Precision:  0.8909090909090909
#
#
#
# Training Recall:  0.9008097165991903
# Testing Recall:  0.8909090909090909
#
#
#
# Training Accuracy:  0.9629629629629629
# Testing Accuracy:  0.9535483870967741
#
#
#
# Training F1-Score:  0.9118852459016394
# Testing F1-Score:  0.8909090909090909

# %%
#warning: may take a while to load (30 seconds to 1 min usually)
#ax = sns.pairplot(merged_df_no_sen, hue = "dem_win")

# %%
sns.heatmap(merged_df_no_sen.corr(), annot = False)
# Out:
# <Axes: >

# %%
# should drop white_pct because perfect multicollinear with nonwhite_pct, should drop age65andolder for same reason, going to run a l1 penalty
#logistic regression to see if that makes it clearer which is better

# %%
def cross_validation_l1(X_train, y_train, c, num_split = 10):
    
    X_train = X_train.values
    y_train = y_train.values
    
    score_train_list = []
    score_val_list = []
    
    for train_index, valid_index in KFold(n_splits = num_split).split(X_train):
        X_train_fold, X_val_fold = X_train[train_index], X_train[valid_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[valid_index]
        scaler = MinMaxScaler()
        X_tf_sc = scaler.fit_transform(X_train_fold)
        X_vld_sc = scaler.transform(X_val_fold)

        logreg = LogisticRegression(fit_intercept=False, penalty = 'l1', solver='liblinear', C = c)
        logreg.fit(X_tf_sc, y_train_fold)

        accuracy_train = logreg.score(X_tf_sc, y_train_fold)
        accuracy_val = logreg.score(X_vld_sc, y_val_fold)
        score_val_list.append(accuracy_val)
        score_train_list.append(accuracy_train)
    return {'c': c, 'train': np.mean(score_train_list), 'validation': np.mean(score_val_list)}

# %%
C_list = [1e-4,1e-3, 1e-2, 1e-1, 1, 10, 100, 1e3, 1e4]
crossval_df_l1 = pd.DataFrame(columns = ['c', 'train', 'validation'])
for c in C_list:
    crossval_df_l1 = crossval_df_l1._append(cross_validation_l1(X_train, y_train, c, 10), ignore_index = True)

# %%
crossval_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   c           9 non-null      float64
#  1   train       9 non-null      float64
#  2   validation  9 non-null      float64
# dtypes: float64(3)
# memory usage: 344.0 bytes

# %%
crossval_df_l1.iloc[crossval_df_l1['validation'].idxmax()]
# Out:
# c             10.000000
# train          0.962006
# validation     0.961662
# Name: 5, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots()
sns.lineplot(x = np.log10(C_list), y = crossval_df_l1['validation'], marker = 's', ax = ax)
ax.set_xlabel('Log(C)')
ax.set_ylabel('Mean Accuracy')
ax.set_title('Accuracy averaged on validation folds')
plt.show()

# %%
fulltrain_scaler_l1 = MinMaxScaler()
X_train_scaled = fulltrain_scaler_l1.fit_transform(X_train)
X_test_scaled = fulltrain_scaler_l1.transform(X_test)
logreg_final_l1 = LogisticRegression(fit_intercept = False, penalty = 'l1', solver = 'liblinear', C = 10)
logreg_final_l1.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(C=10, fit_intercept=False, penalty='l1', solver='liblinear')

# %%
y_hat_test = logreg_final.predict(X_test_scaled)
y_hat_train = logreg_final.predict(X_train_scaled)
print('Training Precision: ', precision_score(y_train, y_hat_train))
print('Testing Precision: ', precision_score(y_test, y_hat_test))
print('\n\n')
print('Training Recall: ', recall_score(y_train, y_hat_train))
print('Testing Recall: ', recall_score(y_test, y_hat_test))
print('\n\n')
print('Training Accuracy: ', accuracy_score(y_train, y_hat_train))
print('Testing Accuracy: ', accuracy_score(y_test, y_hat_test))
print('\n\n')
print('Training F1-Score: ', f1_score(y_train, y_hat_train))
print('Testing F1-Score: ', f1_score(y_test, y_hat_test))
# Out:
# Training Precision:  0.9232365145228216
# Testing Precision:  0.8909090909090909
#
#
#
# Training Recall:  0.9008097165991903
# Testing Recall:  0.8909090909090909
#
#
#
# Training Accuracy:  0.9629629629629629
# Testing Accuracy:  0.9535483870967741
#
#
#
# Training F1-Score:  0.9118852459016394
# Testing F1-Score:  0.8909090909090909

# %%
# not much better, gonna use RFE to see what features are best

# %%
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold

min_features_to_select = 1 
clf = LogisticRegression(max_iter = 10000)
cv = StratifiedKFold(5)

rfecv = RFECV(
    estimator=clf,
    step=1,
    cv=cv,
    scoring="accuracy",
    min_features_to_select=min_features_to_select,
    n_jobs=1,
)
rfecv.fit(X, y)

print(f"Optimal number of features: {rfecv.n_features_}")
# Out:
# Optimal number of features: 6

# %%
clf = LogisticRegression(max_iter = 10000)
select = RFECV(estimator=clf, cv=5)
select = select.fit(X, y)
 
print("Feature ranking: ", select.ranking_)
# Out:
# Feature ranking:  [14  6 12  7  5  1  9  8 13 10  4  1  2  3 11  1  1  1  1]

# %%
from numpy import array  
mask = select.get_support()
arr = merged_df_no_sen.to_numpy()
features = array(X.columns) 
best_features = features[mask]
 
print("All features: ", X.shape[1])
print(features)

print("Selected best: ", best_features.shape[0])
print(features[mask])
# Out:
# All features:  19
# ['total_population' 'black_pct' 'hispanic_pct' 'nonwhite_pct'
#  'foreignborn_pct' 'female_pct' 'age29andunder_pct' 'age65andolder_pct'
#  'median_hh_inc' 'clf_unemploy_pct' 'lesshs_pct' 'lesscollege_pct'
#  'lesshs_whites_pct' 'lesscollege_whites_pct' 'rural_pct' 'pres_16_mov'
#  'pres_12_mov' 'house_16_mov' 'cvap_pct']
# Selected best:  6
# ['female_pct' 'lesscollege_pct' 'pres_16_mov' 'pres_12_mov' 'house_16_mov'
#  'cvap_pct']

# %%
features_to_drop_post_RFE = ['total_population', 'hispanic_pct', 'median_hh_inc', 'rural_pct', 'black_pct', 'nonwhite_pct', 'foreignborn_pct',
                            'age29andunder_pct', 'age65andolder_pct', 'clf_unemploy_pct', 'lesshs_pct',
                            'lesscollege_whites_pct', 'lesshs_whites_pct']
df_post_rfe = merged_df_no_sen.drop(columns = features_to_drop_post_RFE)
df_post_rfe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3097 entries, 0 to 3110
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   female_pct       3097 non-null   float64
#  1   lesscollege_pct  3097 non-null   float64
#  2   pres_16_mov      3097 non-null   float64
#  3   pres_12_mov      3097 non-null   float64
#  4   house_16_mov     3097 non-null   float64
#  5   dem_win          3097 non-null   int64
#  6   cvap_pct         3097 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 193.6 KB

# %%
X = df_post_rfe.drop(columns = 'dem_win')
y = df_post_rfe['dem_win']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 21)

# %%
def cross_validation_post_rfe(X_train, y_train, c, num_split = 10):
    
    X_train = X_train.values
    y_train = y_train.values
    
    score_train_list = []
    score_val_list = []
    
    for train_index, valid_index in KFold(n_splits = num_split).split(X_train):
        X_train_fold, X_val_fold = X_train[train_index], X_train[valid_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[valid_index]
        scaler = MinMaxScaler()
        X_tf_sc = scaler.fit_transform(X_train_fold)
        X_vld_sc = scaler.transform(X_val_fold)

        logreg = LogisticRegression(fit_intercept=False, solver='liblinear', C = c)
        logreg.fit(X_tf_sc, y_train_fold)

        accuracy_train = logreg.score(X_tf_sc, y_train_fold)
        accuracy_val = logreg.score(X_vld_sc, y_val_fold)
        score_val_list.append(accuracy_val)
        score_train_list.append(accuracy_train)
    return {'c': c, 'train': np.mean(score_train_list), 'validation': np.mean(score_val_list)}

# %%
C_list = [1e-4,1e-3, 1e-2, 1e-1, 1, 10, 100, 1e3, 1e4]
crossval_df = pd.DataFrame(columns = ['c', 'train', 'validation'])
for c in C_list:
    crossval_df = crossval_df._append(cross_validation(X_train, y_train, c, 10), ignore_index = True)

# %%
crossval_df.iloc[crossval_df['validation'].idxmax()]
# Out:
# c             100.000000
# train           0.956312
# validation      0.956062
# Name: 6, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots()
sns.lineplot(x = np.log10(C_list), y = crossval_df['validation'], marker = 's', ax = ax)
ax.set_xlabel('Log(C)')
ax.set_ylabel('Mean Accuracy')
ax.set_title('Accuracy averaged on validation folds')
plt.show()

# %%
fulltrain_scaler = MinMaxScaler()
X_train_scaled = fulltrain_scaler.fit_transform(X_train)
X_test_scaled = fulltrain_scaler.transform(X_test)
logreg_final = LogisticRegression(fit_intercept = False, solver = 'liblinear', C = 10)
logreg_final.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(C=10, fit_intercept=False, solver='liblinear')

# %%
y_hat_test = logreg_final.predict(X_test_scaled)
y_hat_train = logreg_final.predict(X_train_scaled)
print('Training Precision: ', precision_score(y_train, y_hat_train))
print('Testing Precision: ', precision_score(y_test, y_hat_test))
print('\n\n')
print('Training Recall: ', recall_score(y_train, y_hat_train))
print('Testing Recall: ', recall_score(y_test, y_hat_test))
print('\n\n')
print('Training Accuracy: ', accuracy_score(y_train, y_hat_train))
print('Testing Accuracy: ', accuracy_score(y_test, y_hat_test))
print('\n\n')
print('Training F1-Score: ', f1_score(y_train, y_hat_train))
print('Testing F1-Score: ', f1_score(y_test, y_hat_test))
# Out:
# Training Precision:  0.9113924050632911
# Testing Precision:  0.8795180722891566
#
#
#
# Training Recall:  0.8744939271255061
# Testing Recall:  0.8848484848484849
#
#
#
# Training Accuracy:  0.9552110249784669
# Testing Accuracy:  0.9496774193548387
#
#
#
# Training F1-Score:  0.8925619834710744
# Testing F1-Score:  0.8821752265861027

# %%
mov_df
# Out:
#       total_population      cvap  black_pct  hispanic_pct  nonwhite_pct  \
# 0              55049.0   40690.0  18.370906      2.572254     24.316518
# 1             199510.0  151770.0   9.225603      4.366698     16.821212
# 2              26614.0   20375.0  47.888329      4.309762     54.114376
# 3              22572.0   17590.0  21.212121      2.223994     25.234804
# 4              57704.0   42430.0   1.557951      8.727298     12.342299
# ...                ...       ...        ...           ...           ...
# 3106           44812.0   30565.0   0.865840     15.859591     20.184326
# 3107           22623.0   16335.0   0.614419     15.174822     18.799452
# 3108           20893.0   14355.0   0.186665      8.959939     12.281625
# 3109            8351.0    6135.0   0.790325     13.962400     17.602682
# 3110            7175.0    5565.0   0.250871      1.003484      7.777003
#
#       foreignborn_pct  female_pct  age29andunder_pct  age65andolder_pct  \
# 0            1.838362   51.176225          40.037058          13.978456
# 1            3.269510   51.194928          35.474412          18.714851
# 2            2.859397   46.498084          37.664387          16.528895
# 3            1.351232   46.464646          37.329435          14.885699
# 4            4.271801   50.485235          37.240053          17.192916
# ...               ...         ...                ...                ...
# 3106         5.509685   47.824244          44.153352           9.417120
# 3107        11.475048   48.097069          35.569995          11.837510
# 3108         3.986981   49.327526          43.205858          10.678218
# 3109         3.783978   51.359119          34.774279          19.650341
# 3110         4.083624   47.958188          33.282230          18.355401
#
#       median_hh_inc  clf_unemploy_pct  lesshs_pct  lesscollege_pct  \
# 0           53099.0          5.591657   12.417046        75.407229
# 1           51365.0          6.286843    9.972418        70.452889
# 2           33956.0         12.824738   26.235928        87.132213
# 3           39776.0          7.146827   19.301587        88.000000
# 4           46212.0          5.953833   19.968585        86.950243
# ...             ...               ...         ...              ...
# 3106        68233.0          5.072255    9.314606        78.628507
# 3107        75594.0          2.123447    4.633570        46.211584
# 3108        53323.0          6.390755   10.361224        81.793082
# 3109        46212.0          7.441860   12.577108        78.923920
# 3110        55640.0          3.610949    8.592392        81.193281
#
#       lesshs_whites_pct  lesscollege_whites_pct  rural_pct  pres_16_mov  \
# 0             10.002112               74.065601  42.002162    -0.489969
# 1              7.842227               68.405607  42.279099    -0.571601
# 2             19.579752               81.364746  67.789635    -0.055688
# 3             15.020490               87.471774  68.352607    -0.551536
# 4             16.643368               86.163610  89.951502    -0.809090
# ...                 ...                     ...        ...          ...
# 3106           6.238463               76.606813  10.916313    -0.520899
# 3107           1.526877               41.769504  46.430920     0.268710
# 3108           8.806312               81.080852  43.095937    -0.584652
# 3109          10.299738               75.980688  35.954529    -0.623755
# 3110           7.342144               81.141179  54.536626    -0.775383
#
#       pres_12_mov  house_16_mov  target_mov
# 0       -0.460304     -0.280756   -0.365065
# 1       -0.557688     -0.571601   -0.542381
# 2        0.031454      0.100637   -0.003471
# 3       -0.466746     -0.542860   -0.545269
# 4       -0.740940     -0.805394   -0.797432
# ...           ...           ...         ...
# 3106    -0.393844     -0.155873   -0.293343
# 3107     0.118196      0.236655    0.303734
# 3108    -0.584026     -0.450408   -0.525713
# 3109    -0.562880     -0.500388   -0.542005
# 3110    -0.714201     -0.514838   -0.648405
#
# [3097 rows x 20 columns]

# %%
mov_df['mov_scale'] = 0
mov_df.loc[(mov_df['target_mov'] >= -1) & (mov_df['target_mov'] <= -.20), 'mov_scale'] = 1
mov_df.loc[(mov_df['target_mov'] > -.20) & (mov_df['target_mov'] <= -.10), 'mov_scale'] = 2
mov_df.loc[(mov_df['target_mov'] > -.10) & (mov_df['target_mov'] <= 0), 'mov_scale'] = 3
mov_df.loc[(mov_df['target_mov'] > 0) & (mov_df['target_mov'] <= .10), 'mov_scale'] = 4
mov_df.loc[(mov_df['target_mov'] > .10) & (mov_df['target_mov'] <= .20), 'mov_scale'] = 5
mov_df.loc[(mov_df['target_mov'] > .20) & (mov_df['target_mov'] <= 1), 'mov_scale'] = 6

# %%
mov_df
# Out:
#       total_population      cvap  black_pct  hispanic_pct  nonwhite_pct  \
# 0              55049.0   40690.0  18.370906      2.572254     24.316518
# 1             199510.0  151770.0   9.225603      4.366698     16.821212
# 2              26614.0   20375.0  47.888329      4.309762     54.114376
# 3              22572.0   17590.0  21.212121      2.223994     25.234804
# 4              57704.0   42430.0   1.557951      8.727298     12.342299
# ...                ...       ...        ...           ...           ...
# 3106           44812.0   30565.0   0.865840     15.859591     20.184326
# 3107           22623.0   16335.0   0.614419     15.174822     18.799452
# 3108           20893.0   14355.0   0.186665      8.959939     12.281625
# 3109            8351.0    6135.0   0.790325     13.962400     17.602682
# 3110            7175.0    5565.0   0.250871      1.003484      7.777003
#
#       foreignborn_pct  female_pct  age29andunder_pct  age65andolder_pct  \
# 0            1.838362   51.176225          40.037058          13.978456
# 1            3.269510   51.194928          35.474412          18.714851
# 2            2.859397   46.498084          37.664387          16.528895
# 3            1.351232   46.464646          37.329435          14.885699
# 4            4.271801   50.485235          37.240053          17.192916
# ...               ...         ...                ...                ...
# 3106         5.509685   47.824244          44.153352           9.417120
# 3107        11.475048   48.097069          35.569995          11.837510
# 3108         3.986981   49.327526          43.205858          10.678218
# 3109         3.783978   51.359119          34.774279          19.650341
# 3110         4.083624   47.958188          33.282230          18.355401
#
#       median_hh_inc  ...  lesshs_pct  lesscollege_pct  lesshs_whites_pct  \
# 0           53099.0  ...   12.417046        75.407229          10.002112
# 1           51365.0  ...    9.972418        70.452889           7.842227
# 2           33956.0  ...   26.235928        87.132213          19.579752
# 3           39776.0  ...   19.301587        88.000000          15.020490
# 4           46212.0  ...   19.968585        86.950243          16.643368
# ...             ...  ...         ...              ...                ...
# 3106        68233.0  ...    9.314606        78.628507           6.238463
# 3107        75594.0  ...    4.633570        46.211584           1.526877
# 3108        53323.0  ...   10.361224        81.793082           8.806312
# 3109        46212.0  ...   12.577108        78.923920          10.299738
# 3110        55640.0  ...    8.592392        81.193281           7.342144
#
#       lesscollege_whites_pct  rural_pct  pres_16_mov  pres_12_mov  \
# 0                  74.065601  42.002162    -0.489969    -0.460304
# 1                  68.405607  42.279099    -0.571601    -0.557688
# 2                  81.364746  67.789635    -0.055688     0.031454
# 3                  87.471774  68.352607    -0.551536    -0.466746
# 4                  86.163610  89.951502    -0.809090    -0.740940
# ...                      ...        ...          ...          ...
# 3106               76.606813  10.916313    -0.520899    -0.393844
# 3107               41.769504  46.430920     0.268710     0.118196
# 3108               81.080852  43.095937    -0.584652    -0.584026
# 3109               75.980688  35.954529    -0.623755    -0.562880
# 3110               81.141179  54.536626    -0.775383    -0.714201
#
#       house_16_mov  target_mov  mov_scale
# 0        -0.280756   -0.365065          1
# 1        -0.571601   -0.542381          1
# 2         0.100637   -0.003471          3
# 3        -0.542860   -0.545269          1
# 4        -0.805394   -0.797432          1
# ...            ...         ...        ...
# 3106     -0.155873   -0.293343          1
# 3107      0.236655    0.303734          6
# 3108     -0.450408   -0.525713          1
# 3109     -0.500388   -0.542005          1
# 3110     -0.514838   -0.648405          1
#
# [3097 rows x 21 columns]

# %%
X = mov_df.drop(columns = ['mov_scale', 'target_mov'])
y = mov_df['mov_scale']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 21)

# %%
def cross_validation(X_train, y_train, c, num_split = 10):
    
    X_train = X_train.values
    y_train = y_train.values
    
    score_train_list = []
    score_val_list = []
    
    for train_index, valid_index in KFold(n_splits = num_split).split(X_train):
        X_train_fold, X_val_fold = X_train[train_index], X_train[valid_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[valid_index]
        scaler = MinMaxScaler()
        X_tf_sc = scaler.fit_transform(X_train_fold)
        X_vld_sc = scaler.transform(X_val_fold)

        logreg = LogisticRegression(fit_intercept=False, solver='liblinear', C = c)
        logreg.fit(X_tf_sc, y_train_fold)

        accuracy_train = logreg.score(X_tf_sc, y_train_fold)
        accuracy_val = logreg.score(X_vld_sc, y_val_fold)
        score_val_list.append(accuracy_val)
        score_train_list.append(accuracy_train)
    return {'c': c, 'train': np.mean(score_train_list), 'validation': np.mean(score_val_list)}

# %%
C_list = [1e-4,1e-3, 1e-2, 1e-1, 1, 10, 100, 1e3, 1e4]
crossval_df = pd.DataFrame(columns = ['c', 'train', 'validation'])
for c in C_list:
    crossval_df = crossval_df._append(cross_validation(X_train, y_train, c, 10), ignore_index = True)

# %%
crossval_df.head()
# Out:
#         c     train  validation
# 0  0.0001  0.639966    0.639983
# 1  0.0010  0.639966    0.639983
# 2  0.0100  0.675711    0.674434
# 3  0.1000  0.738444    0.737304
# 4  1.0000  0.744521    0.743768

# %%
crossval_df.iloc[crossval_df['validation'].idxmax()]
# Out:
# c             1000.000000
# train            0.770265
# validation       0.761416
# Name: 7, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots()
sns.lineplot(x = np.log10(C_list), y = crossval_df['validation'], marker = 's', ax = ax)
ax.set_xlabel('Log(C)')
ax.set_ylabel('Mean Accuracy')
ax.set_title('Accuracy averaged on validation folds')
plt.show()

# %%
fulltrain_scaler = MinMaxScaler()
X_train_scaled = fulltrain_scaler.fit_transform(X_train)
X_test_scaled = fulltrain_scaler.transform(X_test)
logreg_final = LogisticRegression(fit_intercept = False, solver = 'liblinear', C = 1000)
logreg_final.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(C=1000, fit_intercept=False, solver='liblinear')

# %%
y_hat_test = logreg_final.predict(X_test_scaled)
y_hat_train = logreg_final.predict(X_train_scaled)
print('Training Precision: ', precision_score(y_train, y_hat_train, average = 'micro'))
print('Testing Precision: ', precision_score(y_test, y_hat_test, average = 'micro'))
print('\n\n')
print('Training Recall: ', recall_score(y_train, y_hat_train, average = 'micro'))
print('Testing Recall: ', recall_score(y_test, y_hat_test, average = 'micro'))
print('\n\n')
print('Training Accuracy: ', accuracy_score(y_train, y_hat_train))
print('Testing Accuracy: ', accuracy_score(y_test, y_hat_test))
print('\n\n')
print('Training F1-Score: ', f1_score(y_train, y_hat_train, average = 'micro'))
print('Testing F1-Score: ', f1_score(y_test, y_hat_test, average = 'micro'))
# Out:
# Training Precision:  0.7700258397932817
# Testing Precision:  0.7445161290322581
#
#
#
# Training Recall:  0.7700258397932817
# Testing Recall:  0.7445161290322581
#
#
#
# Training Accuracy:  0.7700258397932817
# Testing Accuracy:  0.7445161290322581
#
#
#
# Training F1-Score:  0.7700258397932817
# Testing F1-Score:  0.7445161290322581

# %%
lightweight_drop = ['total_population', 'hispanic_pct', 'median_hh_inc', 'rural_pct', 'black_pct', 'nonwhite_pct', 'foreignborn_pct',
                            'age29andunder_pct', 'age65andolder_pct', 'clf_unemploy_pct', 'lesshs_pct',
                            'lesscollege_whites_pct', 'mov_scale', 'target_mov']
X = mov_df.drop(columns = ['mov_scale', 'target_mov'])
y = mov_df['mov_scale']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 21)

# %%
dem_pop_df = merged_df.loc[(merged_df['dem_win'] == 1)]
rep_pop_df = merged_df.loc[(merged_df['dem_win'] == 0)]
dem_pop_df = dem_pop_df['total_population']
rep_pop_df = rep_pop_df['total_population']

# %%
fig, ax = plt.subplots()

ax.hist(dem_pop_df, bins = 20, histtype = 'step', color ='blue', label = 'Dem win', alpha = 0.7)
ax.hist(rep_pop_df, bins = 20, histtype = 'step', color ='red', label = 'Rep win', alpha = 0.7)
ax.set_xlabel('Size of County')
ax.set_ylabel('Number of Counties')
ax.set_title('Population Distribution of County by Party Win')
ax.legend(loc = 'upper right')
plt.yscale('log')
plt.show()
